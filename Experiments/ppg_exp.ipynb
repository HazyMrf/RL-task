# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash

    # !pip -q install gymnasium[mujoco]==1.0.0

    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %%
from tqdm import tqdm

# %%
from env import make_env, make_vec_env
env = make_env(render_mode="rgb_array")
print("Observation space: ", env.observation_space)
print("Action space: ", env.action_space)
# Out:
# Observation space:  Box(-inf, inf, (17,), float64)
# Action space:  Box(-1.0, 1.0, (6,), float32)

# %%
import matplotlib.pyplot as plt

env.reset()
plt.imshow(env.render())
# Out:
# libGL error: MESA-LOADER: failed to open radeonsi: /usr/lib/dri/radeonsi_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: radeonsi
# libGL error: MESA-LOADER: failed to open radeonsi: /usr/lib/dri/radeonsi_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: radeonsi
# libGL error: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: swrast
# /home/maryna/anaconda3/envs/RL_course/lib/python3.9/site-packages/glfw/__init__.py:917: GLFWError: (65543) b'GLX: Failed to create context: BadValue (integer parameter out of range for operation)'
#   warnings.warn(message, GLFWError)
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import matplotlib.pyplot as plt
#       3 env.reset()
# ----> 4 plt.imshow(env.render())
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/core.py:332, in Wrapper.render(self)
#     330 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     331     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 332     return self.env.render()
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/wrappers/common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/core.py:332, in Wrapper.render(self)
#     330 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     331     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 332     return self.env.render()
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/wrappers/common.py:301, in PassiveEnvChecker.render(self)
#     299 if self.checked_render is False:
#     300     self.checked_render = True
# --> 301     return env_render_passive_checker(self.env)
#     302 else:
#     303     return self.env.render()
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:361, in env_render_passive_checker(env)
#     355     else:
#     356         assert env.render_mode is None or env.render_mode in render_modes, (
#     357             "The environment was initialized successfully however with an unsupported render mode. "
#     358             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     359         )
# --> 361 result = env.render()
#     362 if env.render_mode is not None:
#     363     _check_render_return(env.render_mode, result)
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_env.py:164, in MujocoEnv.render(self)
#     160 def render(self):
#     161     """
#     162     Render a frame from the MuJoCo simulation as specified by the render_mode.
#     163     """
# --> 164     return self.mujoco_renderer.render(self.render_mode)
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:706, in MujocoRenderer.render(self, render_mode)
#     693 def render(
#     694     self,
#     695     render_mode: Optional[str],
#     696 ):
#     697     """Renders a frame of the simulation in a specific format and camera view.
#     698
#     699     Args:
#    (...)
#     703         If render_mode is "rgb_array" or "depth_array" it returns a numpy array in the specified format. "human" render mode does not return anything.
#     704     """
# --> 706     viewer = self._get_viewer(render_mode=render_mode)
#     708     if render_mode in ["rgb_array", "depth_array"]:
#     709         return viewer.render(render_mode=render_mode, camera_id=self.camera_id)
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:730, in MujocoRenderer._get_viewer(self, render_mode)
#     721     self.viewer = WindowViewer(
#     722         self.model,
#     723         self.data,
#    (...)
#     727         self._vopt,
#     728     )
#     729 elif render_mode in {"rgb_array", "depth_array"}:
# --> 730     self.viewer = OffScreenViewer(
#     731         self.model,
#     732         self.data,
#     733         self.width,
#     734         self.height,
#     735         self.max_geom,
#     736         self._vopt,
#     737     )
#     738 else:
#     739     raise AttributeError(
#     740         f"Unexpected mode: {render_mode}, expected modes: human, rgb_array, or depth_array"
#     741     )
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:155, in OffScreenViewer.__init__(self, model, data, width, height, max_geom, visual_options)
#     143 def __init__(
#     144     self,
#     145     model: "mujoco.MjMujoco",
#    (...)
#     151 ):
#     152     # We must make GLContext before MjrContext
#     153     self._get_opengl_backend(width, height)
# --> 155     super().__init__(model, data, width, height, max_geom, visual_options)
#     157     self._init_camera()
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:67, in BaseRender.__init__(self, model, data, width, height, max_geom, visual_options)
#      64 self.make_context_current()
#      66 # Keep in Mujoco Context
# ---> 67 self.con = mujoco.MjrContext(self.model, mujoco.mjtFontScale.mjFONTSCALE_150)
#      69 self._set_mujoco_buffer()
#
# FatalError: gladLoadGL error

# %%
# !pip install mujoco

# Set up GPU rendering.
# from google.colab import files
import distutils.util
import os
import subprocess
if subprocess.run('nvidia-smi').returncode:
  raise RuntimeError(
      'Cannot communicate with GPU. '
      'Make sure you are using a GPU Colab runtime. '
      'Go to the Runtime menu and select Choose runtime type.')

# Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
# This is usually installed as part of an Nvidia driver package, but the Colab
# kernel doesn't install its driver via APT, and as a result the ICD is missing.
# (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
NVIDIA_ICD_CONFIG_PATH = '/usr/share/glvnd/egl_vendor.d/10_nvidia.json'
if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
  with open(NVIDIA_ICD_CONFIG_PATH, 'w') as f:
    f.write("""{
    "file_format_version" : "1.0.0",
    "ICD" : {
        "library_path" : "libEGL_nvidia.so.0"
    }
}
""")

# Configure MuJoCo to use the EGL rendering backend (requires GPU)
print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl

# Check if installation was succesful.
try:
  print('Checking that the installation succeeded:')
  import mujoco
  mujoco.MjModel.from_xml_string('<mujoco/>')
except Exception as e:
  raise e from RuntimeError(
      'Something went wrong during installation. Check the shell output above '
      'for more information.\n'
      'If using a hosted Colab runtime, make sure you enable GPU acceleration '
      'by going to the Runtime menu and selecting "Choose runtime type".')

print('Installation successful.')

# Other imports and helper functions
import time
import itertools
import numpy as np

# Graphics and plotting.
print('Installing mediapy:')
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
import mediapy as media
import matplotlib.pyplot as plt

# More legible printing from numpy.
np.set_printoptions(precision=3, suppress=True, linewidth=100)

from IPython.display import clear_output
clear_output()

# %%
xml = """
<mujoco>
  <worldbody>
    <geom name="red_box" type="box" size=".2 .2 .2" rgba="1 0 0 1"/>
    <geom name="green_sphere" pos=".2 .2 .2" size=".1" rgba="0 1 0 1"/>
  </worldbody>
</mujoco>
"""
model = mujoco.MjModel.from_xml_string(xml)

# %%
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm
from policy import PolicyModel, Policy
from ppo import make_ppo_sampler
from ppg import PPG, EWMA_PPG
from adam import rescale_adam
from IPython.display import clear_output

# Создаём окружения
num_envs = 2
envs = {num_minibatches: make_vec_env(num_envs=num_envs) for num_minibatches in [8, 16, 32]}

# Определяем размеры состояний и действий
state_dim = envs[8].single_observation_space.shape[0]
action_dim = envs[8].single_action_space.shape[0]

# Создаём модели
models = {}
optimizers = {}
ppos = {}
schedulers = {}
num_default_minibatches = 32
num_minibatches_list = [8, 16, 32]  # Разные размеры мини-батчей

for num_minibatches in num_minibatches_list:
    for algo in [PPG, EWMA_PPG]:
        env_curr = make_vec_env(num_envs=num_envs)
        model = PolicyModel(state_dim, action_dim).cpu()
        policy = Policy(model)
        
        sampler = make_ppo_sampler(env_curr, policy, num_minibatches=num_minibatches)
        optimizer = torch.optim.Adam(policy.model.parameters(), lr=3e-4, eps=1e-5)
        
        if algo is EWMA_PPG:
            C = num_default_minibatches / num_minibatches
            rescale_adam(optimizer=optimizer, C=C)

        if algo is EWMA_PPG:
            beta_ewma = 1 - (1 / (num_minibatches + 1))
            ppg = algo(policy, optimizer, beta_ewma=beta_ewma)
        else:
            ppg = algo(policy, optimizer)

        lr_mult = lambda epoch: (1 - (epoch / 150000))
        sched = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_mult)
        
        models[(algo.__name__, num_minibatches)] = (policy, sampler, ppg, env_curr)
        optimizers[(algo.__name__, num_minibatches)] = optimizer
        schedulers[(algo.__name__, num_minibatches)] = sched

# Инициализируем массивы для хранения результатов
steps = []
rewards = {(algo.__name__, num_minibatches): [] for num_minibatches in num_minibatches_list for algo in [PPG, EWMA_PPG]}
n_update = 100  # Как часто обновлять график

# Основной цикл обучения
n_iter = 50000
N_PI = 32
for i in tqdm(range(n_iter)):
    for key in models:
        policy, sampler, ppg, env_curr = models[key]
        optimizer = optimizers[key]
        sched = schedulers[key]
        
        trajectory = sampler.get_next()
        ppg.step(trajectory)
        if ((i + 1) % N_PI == 0):
            ppg.run_aux_phase()
        sched.step()
    
    if (i + 1) % n_update == 0:
        steps.append(i)
        for key in models:
            env_curr = models[key][-1]
            rewards[key].append(env_curr.env.env.env.return_queue[-1])
        
        clear_output(wait=True)  # Удаляет старый график перед обновлением
        plt.figure(figsize=(10, 18))
        
        plt.subplot(3, 1, 1)
        for num_minibatches in num_minibatches_list:
            plt.plot(steps, rewards[("PPG", num_minibatches)], label=f"PPG minibatches={num_minibatches}")
            plt.plot(steps, rewards[("EWMA_PPG", num_minibatches)], '--', label=f"EWMA_PPG minibatches={num_minibatches}")
        
        plt.legend()
        plt.title("PPG vs EWMA_PPG - Reward over time")
        plt.xlabel("Total steps")
        plt.ylabel("Reward")
        plt.grid()

        # График 2: Только PPG с разными размерами мини-батчей
        plt.subplot(3, 1, 2)
        for num_minibatches in num_minibatches_list:
            plt.plot(steps, rewards[("PPG", num_minibatches)], label=f"PPG minibatches={num_minibatches}")
        
        plt.legend()
        plt.title("PPG - Reward over time")
        plt.xlabel("Total steps")
        plt.ylabel("Reward")
        plt.grid()

        # График 3: Только EWMA_PPG с разными размерами мини-батчей
        plt.subplot(3, 1, 3)
        for num_minibatches in num_minibatches_list:
            plt.plot(steps, rewards[("EWMA_PPG", num_minibatches)], label=f"EWMA_PPG minibatches={num_minibatches}")
        
        plt.legend()
        plt.title("EWMA_PPG - Reward over time")
        plt.xlabel("Total steps")
        plt.ylabel("Reward")
        plt.grid()

        plt.show()
# Out:
#  83%|████████▎ | 41284/50000 [3:24:31<43:10,  3.36it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 67
#      64 sched = schedulers[key]
#      66 trajectory = sampler.get_next()
# ---> 67 ppg.step(trajectory)
#      68 if ((i + 1) % N_PI == 0):
#      69     ppg.run_aux_phase()
#
# File ~/HSE/RL/New_RL/RL-task/Experiments/ppg.py:287, in EWMA_PPG.step(self, trajectory)
#     285 def step(self, trajectory):
#     286     self.optimizer.zero_grad()
# --> 287     loss_val = self.policy_phase_loss(trajectory)
#     288     loss_val.backward()
#     289     nn.utils.clip_grad_norm_(self.policy.model.parameters(), self.max_grad_norm)
#
# File ~/HSE/RL/New_RL/RL-task/Experiments/ppg.py:272, in EWMA_PPG.policy_phase_loss(self, trajectory)
#     267 def policy_phase_loss(self, trajectory):
#     268     """
#     269     Combine decoupled PPO's policy + value losses.
#     270     Also store states+value_targets for the upcoming aux phase.
#     271     """
# --> 272     curr_act = self.policy.act(trajectory["observations"], training=True)
#     273     with torch.no_grad():
#     274         prox_act = self.policy_prox.act(trajectory["observations"], training=True)
#
# File ~/HSE/RL/New_RL/RL-task/Experiments/policy.py:54, in Policy.act(self, inputs, training)
#      52 mean, var = self.model.get_policy(inputs)
#      53 cov_matrix = torch.diag_embed(var)
# ---> 54 normal_distr = MultivariateNormal(mean, cov_matrix)
#      56 actions = normal_distr.sample()
#      57 log_probs = normal_distr.log_prob(actions)
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/torch/distributions/multivariate_normal.py:180, in MultivariateNormal.__init__(self, loc, covariance_matrix, precision_matrix, scale_tril, validate_args)
#     177 self.loc = loc.expand(batch_shape + (-1,))
#     179 event_shape = self.loc.shape[-1:]
# --> 180 super().__init__(batch_shape, event_shape, validate_args=validate_args)
#     182 if scale_tril is not None:
#     183     self._unbroadcasted_scale_tril = scale_tril
#
# File ~/anaconda3/envs/RL_course/lib/python3.9/site-packages/torch/distributions/distribution.py:71, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      69         valid = constraint.check(value)
#      70         if not valid.all():
# ---> 71             raise ValueError(
#      72                 f"Expected parameter {param} "
#      73                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      74                 f"of distribution {repr(self)} "
#      75                 f"to satisfy the constraint {repr(constraint)}, "
#      76                 f"but found invalid values:\n{value}"
#      77             )
#      78 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (128, 6)) of distribution MultivariateNormal(loc: torch.Size([128, 6]), covariance_matrix: torch.Size([128, 6, 6])) to satisfy the constraint IndependentConstraint(Real(), 1), but found invalid values:
# tensor([[nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan]], grad_fn=<ExpandBackward0>)
